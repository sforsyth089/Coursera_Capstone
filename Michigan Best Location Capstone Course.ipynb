# %% [markdown]
# <b>Coursera Peer Review Assignment
# Assess Best Upscale Restaurant Location in Michigan, USA

# %% [markdown]
#  <b>Use the Notebook to build the data frames </b>

# %%
#Import needed items
import pandas as pd
import requests
import numpy as np
from pandas.io.json import json_normalize  
from sklearn.cluster import KMeans

import matplotlib.pyplot as plt
import json

# %%
# Load Michigan Zip Code data with latitude/longitude


# Load data - This is available on my GitHub
MIZip_data=pd.read_csv('https://raw.githubusercontent.com/sforsyth089/Coursera_Capstone/main/MI%20Zip%20Codes%20Lat%20Long.csv', index_col=0)
MIZip_data
# Out:
#                      City State   Latitude  Longitude  Timezone  \
# Zip
# 48082  Saint Clair Shores    MI  42.526965 -82.888090        -5
# 48168        South Monroe    MI  41.885451 -83.418524        -5
# 48637             Merrill    MI  43.410627 -84.339260        -5
# 48336          Farmington    MI  42.458502 -83.346400        -5
# 49935          Iron River    MI  46.108022 -88.700730        -6
# ...                   ...   ...        ...        ...       ...
# 49084           Riverside    MI  42.178035 -86.385570        -5
# 49690        Williamsburg    MI  44.774285 -85.416960        -5
# 49303              Bailey    MI  43.271422 -85.840230        -5
# 49081             Portage    MI  42.171777 -85.617824        -5
# 49446             New Era    MI  43.551783 -86.402650        -5
#
#        Daylight savings time flag               geopoint
# Zip
# 48082                           1   42.526965, -82.88809
# 48168                           1  41.885451, -83.418524
# 48637                           1   43.410627, -84.33926
# 48336                           1    42.458502, -83.3464
# 49935                           1   46.108022, -88.70073
# ...                           ...                    ...
# 49084                           1   42.178035, -86.38557
# 49690                           1   44.774285, -85.41696
# 49303                           1   43.271422, -85.84023
# 49081                           1  42.171777, -85.617824
# 49446                           1   43.551783, -86.40265
#
# [1203 rows x 7 columns]

# %%
#Drop fields that we will not use - timezone and daylight savings flag.

MIZip_data.drop("Timezone", axis=1, inplace=True)
MIZip_data.drop("Daylight savings time flag", axis=1, inplace=True)
MIZip_data

#This is the pure ZIP CODE table with latitide and longitude. Next I'd like to combine with the wealth table.
# Out:
#                      City State   Latitude  Longitude               geopoint
# Zip
# 48082  Saint Clair Shores    MI  42.526965 -82.888090   42.526965, -82.88809
# 48168        South Monroe    MI  41.885451 -83.418524  41.885451, -83.418524
# 48637             Merrill    MI  43.410627 -84.339260   43.410627, -84.33926
# 48336          Farmington    MI  42.458502 -83.346400    42.458502, -83.3464
# 49935          Iron River    MI  46.108022 -88.700730   46.108022, -88.70073
# ...                   ...   ...        ...        ...                    ...
# 49084           Riverside    MI  42.178035 -86.385570   42.178035, -86.38557
# 49690        Williamsburg    MI  44.774285 -85.416960   44.774285, -85.41696
# 49303              Bailey    MI  43.271422 -85.840230   43.271422, -85.84023
# 49081             Portage    MI  42.171777 -85.617824  42.171777, -85.617824
# 49446             New Era    MI  43.551783 -86.402650   43.551783, -86.40265
#
# [1203 rows x 5 columns]

# %%
# Load Michigan Zip Code WEALTH data, Top 25 neighborhoods


# Load data - This is available on my GitHub
MIWealth_data=pd.read_csv('https://raw.githubusercontent.com/sforsyth089/Coursera_Capstone/main/Wealthiest%20Neighborhoods%20in%20MI.csv', index_col=0)
MIWealth_data
# Out:
#       Zipcode          Zip Name    County  Adjusted Gross Income  \
# Rank
# 1       48304  Bloomfield Hills   Oakland               363140.0
# 2       48009        Birmingham   Oakland               304550.0
# 3       48302  Bloomfield Hills   Oakland               297530.0
# 4       48236     Grosse Pointe     Wayne               287490.0
# 5       48301  Bloomfield Hills   Oakland               256820.0
# 6       48226           Detroit     Wayne               256060.0
# 7       48025          Franklin   Oakland               239110.0
# 8       49969        Watersmeet   Gogebic               225040.0
# 9       49301               Ada      Kent               215550.0
# 10      48502             Flint   Genesee               210450.0
# 11      48070  Huntington Woods   Oakland               203820.0
# 12      48168        Northville     Wayne               193950.0
# 13      49636        Glen Arbor  Leelanau               181310.0
# 14      48230     Grosse Pointe     Wayne               177230.0
# 15      49116          Lakeside   Berrien               176180.0
# 16      48323   West Bloomfield   Oakland               171320.0
# 17      48363           Oakland   Oakland               169880.0
# 18      49060   Hickory Corners     Barry               168440.0
# 19      48306         Rochester   Oakland               165470.0
# 20      49654            Leland  Leelanau               161040.0
# 21      48098              Troy   Oakland               160620.0
# 22      48374              Novi   Oakland               155640.0
# 23      48331        Farmington   Oakland               142200.0
# 24      48324   West Bloomfield   Oakland               141940.0
# 25      48167        Northville   Oakland               140930.0
#
#       Median Household Income
# Rank
# 1                    120104.0
# 2                    117670.0
# 3                    129154.0
# 4                    103742.0
# 5                    144659.0
# 6                     57083.0
# 7                    123365.0
# 8                     41375.0
# 9                    127342.0
# 10                    30500.0
# 11                   130417.0
# 12                   133984.0
# 13                    76250.0
# 14                   110549.0
# 15                    58269.0
# 16                   113008.0
# 17                   127946.0
# 18                    63750.0
# 19                   147303.0
# 20                    61438.0
# 21                   124183.0
# 22                   138984.0
# 23                   109847.0
# 24                   110761.0
# 25                    94788.0

# %%
# Out:
#       Zipcode          Zip Name    County  Adjusted Gross Income  \
# Rank
# 1       48304  Bloomfield Hills   Oakland               363140.0
# 2       48009        Birmingham   Oakland               304550.0
# 3       48302  Bloomfield Hills   Oakland               297530.0
# 4       48236     Grosse Pointe     Wayne               287490.0
# 5       48301  Bloomfield Hills   Oakland               256820.0
# 6       48226           Detroit     Wayne               256060.0
# 7       48025          Franklin   Oakland               239110.0
# 8       49969        Watersmeet   Gogebic               225040.0
# 9       49301               Ada      Kent               215550.0
# 10      48502             Flint   Genesee               210450.0
# 11      48070  Huntington Woods   Oakland               203820.0
# 12      48168        Northville     Wayne               193950.0
# 13      49636        Glen Arbor  Leelanau               181310.0
# 14      48230     Grosse Pointe     Wayne               177230.0
# 15      49116          Lakeside   Berrien               176180.0
# 16      48323   West Bloomfield   Oakland               171320.0
# 17      48363           Oakland   Oakland               169880.0
# 18      49060   Hickory Corners     Barry               168440.0
# 19      48306         Rochester   Oakland               165470.0
# 20      49654            Leland  Leelanau               161040.0
# 21      48098              Troy   Oakland               160620.0
# 22      48374              Novi   Oakland               155640.0
# 23      48331        Farmington   Oakland               142200.0
# 24      48324   West Bloomfield   Oakland               141940.0
# 25      48167        Northville   Oakland               140930.0
#
#       Median Household Income
# Rank
# 1                    120104.0
# 2                    117670.0
# 3                    129154.0
# 4                    103742.0
# 5                    144659.0
# 6                     57083.0
# 7                    123365.0
# 8                     41375.0
# 9                    127342.0
# 10                    30500.0
# 11                   130417.0
# 12                   133984.0
# 13                    76250.0
# 14                   110549.0
# 15                    58269.0
# 16                   113008.0
# 17                   127946.0
# 18                    63750.0
# 19                   147303.0
# 20                    61438.0
# 21                   124183.0
# 22                   138984.0
# 23                   109847.0
# 24                   110761.0
# 25                    94788.0

# %% [markdown]
# <b>Combine the Zip and Wealth data to make a data frame.  Drop anything not on the wealth table. </b>

# %%
#merging the tables to make 1 new table
df_MItotalwealth = pd.merge(MIZip_data, MIWealth_data, how='left', left_on = 'Zip', right_on = 'Zipcode')

df_MItotalwealth
#This is the merged table. There is too much stuff need to remove the rows that do not make the wealth list.
# Out:
#                     City State   Latitude  Longitude               geopoint  \
# 0     Saint Clair Shores    MI  42.526965 -82.888090   42.526965, -82.88809
# 1           South Monroe    MI  41.885451 -83.418524  41.885451, -83.418524
# 2                Merrill    MI  43.410627 -84.339260   43.410627, -84.33926
# 3             Farmington    MI  42.458502 -83.346400    42.458502, -83.3464
# 4             Iron River    MI  46.108022 -88.700730   46.108022, -88.70073
# ...                  ...   ...        ...        ...                    ...
# 1198           Riverside    MI  42.178035 -86.385570   42.178035, -86.38557
# 1199        Williamsburg    MI  44.774285 -85.416960   44.774285, -85.41696
# 1200              Bailey    MI  43.271422 -85.840230   43.271422, -85.84023
# 1201             Portage    MI  42.171777 -85.617824  42.171777, -85.617824
# 1202             New Era    MI  43.551783 -86.402650   43.551783, -86.40265
#
#       Zipcode    Zip Name County  Adjusted Gross Income  \
# 0         NaN         NaN    NaN                    NaN
# 1     48168.0  Northville  Wayne               193950.0
# 2         NaN         NaN    NaN                    NaN
# 3         NaN         NaN    NaN                    NaN
# 4         NaN         NaN    NaN                    NaN
# ...       ...         ...    ...                    ...
# 1198      NaN         NaN    NaN                    NaN
# 1199      NaN         NaN    NaN                    NaN
# 1200      NaN         NaN    NaN                    NaN
# 1201      NaN         NaN    NaN                    NaN
# 1202      NaN         NaN    NaN                    NaN
#
#       Median Household Income
# 0                         NaN
# 1                    133984.0
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 1198                      NaN
# 1199                      NaN
# 1200                      NaN
# 1201                      NaN
# 1202                      NaN
#
# [1203 rows x 10 columns]

# %%
#If the zip code is NaN, a match was not found and we drop.

dfwealthclean = df_MItotalwealth.dropna()

dfwealthclean
# Out:
#                   City State   Latitude  Longitude               geopoint  \
# 1         South Monroe    MI  41.885451 -83.418524  41.885451, -83.418524
# 5      West Bloomfield    MI  42.572442 -83.371590   42.572442, -83.37159
# 50             Detroit    MI  42.331821 -83.048880   42.331821, -83.04888
# 88       Grosse Pointe    MI  42.386087 -82.924260   42.386087, -82.92426
# 143    Hickory Corners    MI  42.424387 -85.405500    42.424387, -85.4055
# 150           Franklin    MI  42.524134 -83.254540   42.524134, -83.25454
# 247          Rochester    MI  42.708151 -83.165840   42.708151, -83.16584
# 261              Flint    MI  43.014077 -83.690120   43.014077, -83.69012
# 299            Oakland    MI  42.765582 -83.172810   42.765582, -83.17281
# 350      Grosse Pointe    MI  42.425836 -82.900030   42.425836, -82.90003
# 366           Lakeside    MI  41.848782 -86.670440   41.848782, -86.67044
# 373                Ada    MI  42.972520 -85.477980    42.97252, -85.47798
# 383             Leland    MI  45.023384 -85.756970   45.023384, -85.75697
# 390   Bloomfield Hills    MI  42.546445 -83.280830   42.546445, -83.28083
# 514         Northville    MI  42.425506 -83.489450   42.425506, -83.48945
# 539               Troy    MI  42.599133 -83.152350   42.599133, -83.15235
# 547         Farmington    MI  42.508809 -83.408750   42.508809, -83.40875
# 573   Bloomfield Hills    MI  42.586677 -83.229560   42.586677, -83.22956
# 625   Huntington Woods    MI  42.482585 -83.168120   42.482585, -83.16812
# 753         Watersmeet    MI  46.258959 -89.265940   46.258959, -89.26594
# 761         Birmingham    MI  42.544084 -83.215270   42.544084, -83.21527
# 1094        Glen Arbor    MI  44.884904 -85.985880   44.884904, -85.98588
# 1132              Novi    MI  42.467945 -83.517660   42.467945, -83.51766
# 1162  Bloomfield Hills    MI  42.586300 -83.297050     42.5863, -83.29705
# 1187   West Bloomfield    MI  42.595233 -83.399740   42.595233, -83.39974
#
#       Zipcode          Zip Name    County  Adjusted Gross Income  \
# 1     48168.0        Northville     Wayne               193950.0
# 5     48323.0   West Bloomfield   Oakland               171320.0
# 50    48226.0           Detroit     Wayne               256060.0
# 88    48230.0     Grosse Pointe     Wayne               177230.0
# 143   49060.0   Hickory Corners     Barry               168440.0
# 150   48025.0          Franklin   Oakland               239110.0
# 247   48306.0         Rochester   Oakland               165470.0
# 261   48502.0             Flint   Genesee               210450.0
# 299   48363.0           Oakland   Oakland               169880.0
# 350   48236.0     Grosse Pointe     Wayne               287490.0
# 366   49116.0          Lakeside   Berrien               176180.0
# 373   49301.0               Ada      Kent               215550.0
# 383   49654.0            Leland  Leelanau               161040.0
# 390   48301.0  Bloomfield Hills   Oakland               256820.0
# 514   48167.0        Northville   Oakland               140930.0
# 539   48098.0              Troy   Oakland               160620.0
# 547   48331.0        Farmington   Oakland               142200.0
# 573   48304.0  Bloomfield Hills   Oakland               363140.0
# 625   48070.0  Huntington Woods   Oakland               203820.0
# 753   49969.0        Watersmeet   Gogebic               225040.0
# 761   48009.0        Birmingham   Oakland               304550.0
# 1094  49636.0        Glen Arbor  Leelanau               181310.0
# 1132  48374.0              Novi   Oakland               155640.0
# 1162  48302.0  Bloomfield Hills   Oakland               297530.0
# 1187  48324.0   West Bloomfield   Oakland               141940.0
#
#       Median Household Income
# 1                    133984.0
# 5                    113008.0
# 50                    57083.0
# 88                   110549.0
# 143                   63750.0
# 150                  123365.0
# 247                  147303.0
# 261                   30500.0
# 299                  127946.0
# 350                  103742.0
# 366                   58269.0
# 373                  127342.0
# 383                   61438.0
# 390                  144659.0
# 514                   94788.0
# 539                  124183.0
# 547                  109847.0
# 573                  120104.0
# 625                  130417.0
# 753                   41375.0
# 761                  117670.0
# 1094                  76250.0
# 1132                 138984.0
# 1162                 129154.0
# 1187                 110761.0

# %% [markdown]
# <b> Now we will map the MI places and think about a location! </b>

# %% [markdown]
# Create a Michigan Map
#
# Involves importing folium which is a mapping tool.

# %%
import folium #mapping tool

#Detroit latitude and longitude 42.3314° N, 83.0458° W

map_locationMI = folium.Map(location=[42.3314,-83.0458],zoom_start=10)  

for lat, lng, zipc, neighborhood in zip(dfwealthclean['Latitude'],dfwealthclean['Longitude'],dfwealthclean['Zipcode'],dfwealthclean['Zip Name']):
    label = '{}, {}'.format(neighborhood, zipc)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
    [lat,lng],
    radius=5,
    popup=label,
    color='blue',
    fill=True,
    fill_color='#3186cc',
    fill_opacity=0.7,
    parse_html=False).add_to(map_locationMI)
map_locationMI
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Interesting, we see many more blue dots outside of Detroit, but near to Detroit.
# There are also a couple blue dots in the Traverse City area.

# %% [markdown]
# Next we will cluster the neighboor hoods to think about where we are seeing patterns.

# %%
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import matplotlib.colors as colors
dfwealthclean.head()
# Out:
#                 City State   Latitude  Longitude               geopoint  \
# 1       South Monroe    MI  41.885451 -83.418524  41.885451, -83.418524
# 5    West Bloomfield    MI  42.572442 -83.371590   42.572442, -83.37159
# 50           Detroit    MI  42.331821 -83.048880   42.331821, -83.04888
# 88     Grosse Pointe    MI  42.386087 -82.924260   42.386087, -82.92426
# 143  Hickory Corners    MI  42.424387 -85.405500    42.424387, -85.4055
#
#      Zipcode         Zip Name   County  Adjusted Gross Income  \
# 1    48168.0       Northville    Wayne               193950.0
# 5    48323.0  West Bloomfield  Oakland               171320.0
# 50   48226.0          Detroit    Wayne               256060.0
# 88   48230.0    Grosse Pointe    Wayne               177230.0
# 143  49060.0  Hickory Corners    Barry               168440.0
#
#      Median Household Income
# 1                   133984.0
# 5                   113008.0
# 50                   57083.0
# 88                  110549.0
# 143                  63750.0

# %% [markdown]
# This code below does the K means then inserts cluster to the Toronto Only table.

# %%
k=5
MIwealth_clustering = dfwealthclean.drop(['Zipcode','Zip Name', 'City', 'State', 'geopoint', 'County', 'Adjusted Gross Income', 'Median Household Income'],1)
kmeans = KMeans(n_clusters = k,random_state=0).fit(MIwealth_clustering)
kmeans.labels_
dfwealthclean.insert(0, 'Cluster', kmeans.labels_)

# %%
dfwealthclean
# Out:
#       Cluster              City State   Latitude  Longitude  \
# 1           1      South Monroe    MI  41.885451 -83.418524
# 5           1   West Bloomfield    MI  42.572442 -83.371590
# 50          1           Detroit    MI  42.331821 -83.048880
# 88          1     Grosse Pointe    MI  42.386087 -82.924260
# 143         4   Hickory Corners    MI  42.424387 -85.405500
# 150         1          Franklin    MI  42.524134 -83.254540
# 247         1         Rochester    MI  42.708151 -83.165840
# 261         1             Flint    MI  43.014077 -83.690120
# 299         1           Oakland    MI  42.765582 -83.172810
# 350         1     Grosse Pointe    MI  42.425836 -82.900030
# 366         2          Lakeside    MI  41.848782 -86.670440
# 373         4               Ada    MI  42.972520 -85.477980
# 383         0            Leland    MI  45.023384 -85.756970
# 390         1  Bloomfield Hills    MI  42.546445 -83.280830
# 514         1        Northville    MI  42.425506 -83.489450
# 539         1              Troy    MI  42.599133 -83.152350
# 547         1        Farmington    MI  42.508809 -83.408750
# 573         1  Bloomfield Hills    MI  42.586677 -83.229560
# 625         1  Huntington Woods    MI  42.482585 -83.168120
# 753         3        Watersmeet    MI  46.258959 -89.265940
# 761         1        Birmingham    MI  42.544084 -83.215270
# 1094        0        Glen Arbor    MI  44.884904 -85.985880
# 1132        1              Novi    MI  42.467945 -83.517660
# 1162        1  Bloomfield Hills    MI  42.586300 -83.297050
# 1187        1   West Bloomfield    MI  42.595233 -83.399740
#
#                    geopoint  Zipcode          Zip Name    County  \
# 1     41.885451, -83.418524  48168.0        Northville     Wayne
# 5      42.572442, -83.37159  48323.0   West Bloomfield   Oakland
# 50     42.331821, -83.04888  48226.0           Detroit     Wayne
# 88     42.386087, -82.92426  48230.0     Grosse Pointe     Wayne
# 143     42.424387, -85.4055  49060.0   Hickory Corners     Barry
# 150    42.524134, -83.25454  48025.0          Franklin   Oakland
# 247    42.708151, -83.16584  48306.0         Rochester   Oakland
# 261    43.014077, -83.69012  48502.0             Flint   Genesee
# 299    42.765582, -83.17281  48363.0           Oakland   Oakland
# 350    42.425836, -82.90003  48236.0     Grosse Pointe     Wayne
# 366    41.848782, -86.67044  49116.0          Lakeside   Berrien
# 373     42.97252, -85.47798  49301.0               Ada      Kent
# 383    45.023384, -85.75697  49654.0            Leland  Leelanau
# 390    42.546445, -83.28083  48301.0  Bloomfield Hills   Oakland
# 514    42.425506, -83.48945  48167.0        Northville   Oakland
# 539    42.599133, -83.15235  48098.0              Troy   Oakland
# 547    42.508809, -83.40875  48331.0        Farmington   Oakland
# 573    42.586677, -83.22956  48304.0  Bloomfield Hills   Oakland
# 625    42.482585, -83.16812  48070.0  Huntington Woods   Oakland
# 753    46.258959, -89.26594  49969.0        Watersmeet   Gogebic
# 761    42.544084, -83.21527  48009.0        Birmingham   Oakland
# 1094   44.884904, -85.98588  49636.0        Glen Arbor  Leelanau
# 1132   42.467945, -83.51766  48374.0              Novi   Oakland
# 1162     42.5863, -83.29705  48302.0  Bloomfield Hills   Oakland
# 1187   42.595233, -83.39974  48324.0   West Bloomfield   Oakland
#
#       Adjusted Gross Income  Median Household Income
# 1                  193950.0                 133984.0
# 5                  171320.0                 113008.0
# 50                 256060.0                  57083.0
# 88                 177230.0                 110549.0
# 143                168440.0                  63750.0
# 150                239110.0                 123365.0
# 247                165470.0                 147303.0
# 261                210450.0                  30500.0
# 299                169880.0                 127946.0
# 350                287490.0                 103742.0
# 366                176180.0                  58269.0
# 373                215550.0                 127342.0
# 383                161040.0                  61438.0
# 390                256820.0                 144659.0
# 514                140930.0                  94788.0
# 539                160620.0                 124183.0
# 547                142200.0                 109847.0
# 573                363140.0                 120104.0
# 625                203820.0                 130417.0
# 753                225040.0                  41375.0
# 761                304550.0                 117670.0
# 1094               181310.0                  76250.0
# 1132               155640.0                 138984.0
# 1162               297530.0                 129154.0
# 1187               141940.0                 110761.0

# %% [markdown]
# Success - all the neighborhoods have a Cluster assigned

# %% [markdown]
# Next let's map the clusters. Used Detroit as central point. Zoom in/out of map to see more.

# %%
map_MIclusters = folium.Map(location=[42.3314,-83.0458],zoom_start=10)

#colors for mapping
x = np.arange(k)
ys = [i + x + (i*x)**2 for i in range(k)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# markers for mapping
markers_colors = []
for lat, lon, neighborhood, cluster in zip(dfwealthclean['Latitude'], dfwealthclean['Longitude'], dfwealthclean['Zip Name'], dfwealthclean['Cluster']):
    label = folium.Popup(' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_MIclusters)
       
map_MIclusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Analysis:
# Detroit is a thought of a location, however, there are many more purple dots in the Oakland county area around Birmingham where there are high wealth zip codes which we know will aid in success of our restaurant.
